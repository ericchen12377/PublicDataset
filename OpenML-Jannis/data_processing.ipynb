# %%
import pandas as pd

# %%
import os 
work_path = os.getcwd() 
raw_path = work_path + "\\raw"
processed_path = work_path + "\\processed"

# %%
from scipy.io.arff import loadarff
import pandas as pd

data = loadarff(raw_path+"\\file1c558ee247d.arff")
df = pd.DataFrame(data[0])
df.head()
# Out:
#   class        V1        V2        V3        V4        V5        V6        V7  \
# 0  b'3'  0.047095  0.316667  0.288889  0.180925  0.101677  0.252014  0.235673
# 1  b'3'  0.464873  1.000000  0.483333  0.502843  0.233860  0.998355  0.465075
# 2  b'3'  0.053872  0.516667  0.180556  0.431467  0.064608  0.412341  0.151937
# 3  b'1'  0.030475  0.245833  0.175000  0.128515  0.438525  0.207337  0.146200
# 4  b'1'  0.038883  0.256250  0.225000  0.128165  0.618360  0.252958  0.171803
#
#          V8        V9  ...      V45       V46       V47       V48       V49  \
# 0  0.054190  0.485197  ...  62.6329  0.421830  0.401547  0.036195  153.2040
# 1  0.016096  0.038194  ...  31.3279  0.356803  0.439840  0.022729  123.5940
# 2  0.056719  0.422519  ...  25.7490  0.583339  0.611528  0.042459  147.7000
# 3  0.049183  0.291633  ...  33.1253  0.553694  0.417488  0.059169  147.5880
# 4  0.059235  0.325605  ...  62.5253  0.453029  0.687470  0.051630   85.8803
#
#         V50      V51      V52       V53       V54
# 0 -7.584500  21.9080  13.0200  0.086289  1.074020
# 1  0.813364  19.8483  18.3443  0.039786  0.333176
# 2 -0.428918  35.7166  15.8205  0.164682  1.175180
# 3  0.108469  13.0906  21.0650  0.028791  1.215070
# 4 -1.058330  23.8815  10.5757  0.005814  0.222675
#
# [5 rows x 55 columns]

# %%
df.shape
# Out:
# (83733, 55)

# %%
df.to_csv(processed_path+"\\jannis.csv", header=True, index=None)
