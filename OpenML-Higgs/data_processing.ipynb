# %%
import pandas as pd

# %%
import os 
work_path = os.getcwd() 
raw_path = work_path + "\\raw"
processed_path = work_path + "\\processed"

# %%
from scipy.io.arff import loadarff
import pandas as pd

data = loadarff(raw_path+"\\phpZLgL9q.arff")
df = pd.DataFrame(data[0])
df.head()
# Out:
#   class  lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0  b'1'   0.907542    0.329147    0.359412                  1.497970
# 1  b'1'   0.798835    1.470639   -1.635975                  0.453773
# 2  b'0'   1.344385   -0.876626    0.935913                  1.992050
# 3  b'1'   1.105009    0.321356    1.522401                  0.882808
# 4  b'0'   1.595839   -0.607811    0.007075                  1.818450
#
#    missing_energy_phi    jet1pt   jet1eta   jet1phi  jet1b-tag  ...   jet4eta  \
# 0           -0.313010  1.095531 -0.557525 -1.588230   2.173076  ... -1.138930
# 1            0.425629  1.104875  1.282322  1.381664   0.000000  ...  1.128848
# 2            0.882454  1.786066 -1.646778 -0.942383   0.000000  ... -0.678379
# 3           -1.205349  0.681466 -1.070464 -0.921871   0.000000  ... -0.373566
# 4           -0.111906  0.847550 -0.566437  1.581239   2.173076  ... -0.654227
#
#     jet4phi  jet4b-tag      m_jj     m_jjj      m_lv     m_jlv      m_bb  \
# ...

# %%
df.shape
# Out:
# (98050, 29)

# %%
df.to_csv(processed_path+"\\higgs.csv", header=True, index=None)
